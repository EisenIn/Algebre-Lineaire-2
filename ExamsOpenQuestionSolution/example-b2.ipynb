# %%
#turn on pretty print 
from sage.all import *  


#declare a 4x5 matrix over the finite field with 5 elements
F = GF(3) 

M = Matrix(F, 4, 5, [1,2,0,1,2, 0,1,2,0,1, 2,0,1,2,0, 1,2,0,1,2])


#prettyprint M
pretty_print(M)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 12
#       8 M = Matrix(F, Integer(4), Integer(5), [Integer(1),Integer(2),Integer(0),Integer(1),Integer(2), Integer(0),Integer(1),Integer(2),Integer(0),Integer(1), Integer(2),Integer(0),Integer(1),Integer(2),Integer(0), Integer(1),Integer(2),Integer(0),Integer(1),Integer(2)])
#      11 #prettyprint M
# ---> 12 prettyprintprint(M)
#
# NameError: name 'prettyprintprint' is not defined
