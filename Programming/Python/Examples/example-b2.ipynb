# %%
F = GF(3)

# Generate a 3x4 matrix over F

#  with rows being 

A = Matrix (F, 3,4, [1 , 2 , 0 ,1 , 2 , 0 , 1 , 2 , 0 , 1 , 2 , 0 , 1 , 2 , 0 , 1 , 2 , 0 , 1 , 2 ])


print(A)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [5], line 7
#       1 F = GF(Integer(3))
#       3 # Generate a 3x4 matrix over F
#       4
#       5 #  with rows being
# ----> 7 A = matrix (F, Integer(3),Integer(4), [Integer(1) , Integer(2) , Integer(0) ,Integer(1) , Integer(2) , Integer(0) , Integer(1) , Integer(2) , Integer(0) , Integer(1) , Integer(2) , Integer(0) , Integer(1) , Integer(2) , Integer(0) , Integer(1) , Integer(2) , Integer(0) , Integer(1) , Integer(2) ])
#      10 print(A)
#
# File /private/var/tmp/sage-10.2-current/local/var/lib/sage/venv-python3.11.1/lib/python3.11/site-packages/sage/matrix/constructor.pyx:648, in sage.matrix.constructor.matrix (build/cythonized/sage/matrix/constructor.c:5336)()
#     646 """
#     647 immutable = kwds.pop('immutable', False)
# --> 648 M = MatrixArgs(*args, **kwds).matrix()
#     649 if immutable:
# ...
